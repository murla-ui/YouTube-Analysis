# %% [markdown]
# # Analysis of YouTube trending videos in 5 countries

# %% [markdown]
# ## Contents

# %% [markdown]
# - Introduction
# - Data description
# - Data preparation
# - Data analysis
# - Conclusion

# %% [markdown]
# ## 1. Introduction
#
# YouTube is an American online video-sharing platform headquartered in San Bruno, California. Three former PayPal employees—Chad Hurley, Steve Chen, and Jawed Karim—created the service in February 2005. Google bought the site in November 2006 for US$1.65 billion; YouTube now operates as one of Google's subsidiaries.
#
# YouTube allows users to upload, view, rate, share, add to playlists, report, comment on videos, and subscribe to other users. It offers a wide variety of user-generated and corporate media videos. Available content includes video clips, TV show clips, music videos, short and documentary films, audio recordings, movie trailers, live streams, and other content such as video blogging, short original videos, and educational videos. Most content on YouTube is uploaded by individuals, but media corporations including CBS, the BBC, Vevo, and Hulu offer some of their material via YouTube as part of the YouTube partnership program. Unregistered users can only watch (but not upload) videos on the site, while registered users are also permitted to upload an unlimited number of videos and add comments to videos. Age-restricted videos are available only to registered users affirming themselves to be at least 18 years old.
#
# Sourse: https://en.wikipedia.org/wiki/YouTube

# %% [markdown]
# # 2.1 Data description
#
#
# YouTube (the world-famous video sharing website) maintains a list of the top trending videos on the platform. According to Variety magazine, “To determine the year’s top-trending videos, YouTube uses a combination of factors including measuring users interactions (number of views, shares, comments and likes). Note that they’re not the most-viewed videos overall for the calendar year”. Top performers on the YouTube trending list are music videos (such as the famously virile “Gangam Style”), celebrity and/or reality TV performances, and the random dude-with-a-camera viral videos that YouTube is well-known for.
#
# Dataset initially had 10 countries, but in this analysis countries are limitted to India, USA, Canada, Germany and France for the representation of regions. For the puposes of the analysis 5 datasets merged together into one.
#
# Data obtained from 2017 to 2018.
#
# Variables that will be used for analysis:
#
# - Categories
# - Publishing time
# - Tags
# - Views
# - Likes
# - Dislikes
# - Comment count
# - Country
# - Video titles
#
# Sourse: https://www.kaggle.com/datasnaek/youtube-new

# %% [markdown]
# # 2.2 Research questions
#
# - Ratio of trending videos by country
# - Analysis by category (in each country)
# - How many comments, likes and dislikes videos have
# - Likes/dislikes and views/comments ratio trending videos have by category
# - When were trending videos published?

# %% [markdown]
# # 3. Data preparation

# %% [markdown]
# First, 5 csv files are imported.

# %%
import pandas as pd

CA_YT = pd.read_csv('CAvideos.csv')

# %%
CA_YT.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
US_YT = pd.read_csv('USvideos.csv')

# %%
US_YT.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
IN_YT = pd.read_csv('INvideos.csv')

# %%
IN_YT.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc      17.14.11
# 1  zUZ1z7FwLc8      17.14.11
# 2  10L1hZ9qa58      17.14.11
# 3  N1vE8iiEg64      17.14.11
# 4  kJzGH0PVQHQ      17.14.11
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...          HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 3                     Eruma Saani | Tamil vs English      Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
#
#    category_id              publish_time  \
# 0            1  2017-11-12T12:20:39.000Z
# 1           25  2017-11-13T05:43:56.000Z
# 2           24  2017-11-12T15:48:08.000Z
# 3           23  2017-11-12T07:08:48.000Z
# 4           24  2017-11-13T01:14:16.000Z
#
#                                                 tags    views  likes  \
# ...

# %%
FR_YT = pd.read_csv('FRvideos.csv')

# %%
DE_YT = pd.read_csv('DEvideos.csv')

# %% [markdown]
# Second, add new column to all data frames and save it in csv file.

# %%
CA_YT["country"] = "Canada"
CA_YT.to_csv("CAvideos.csv", index=False)

# %%
CA_YT.tail()
# Out:
#           video_id trending_date  \
# 40876  sGolxsMSGfQ      18.14.06
# 40877  8HNuRNi8t70      18.14.06
# 40878  GWlKEM3m2EE      18.14.06
# 40879  lbMKLzQ4cNQ      18.14.06
# 40880  POTgw38-m58      18.14.06
#
#                                                    title     channel_title  \
# 40876                       HOW2: How to Solve a Mystery   Annoying Orange
# 40877                   Eli Lik Lik Episode 13 Partie 01  Elhiwar Ettounsi
# 40878  KINGDOM HEARTS III – SQUARE ENIX E3 SHOWCASE 2...    Kingdom Hearts
# 40879                   Trump Advisor Grovels To Trudeau   The Young Turks
# 40880                   【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班          我愛小明星大跟班
#
#        category_id              publish_time  \
# 40876           24  2018-06-13T18:00:07.000Z
# 40877           24  2018-06-13T19:01:18.000Z
# 40878           20  2018-06-11T17:30:53.000Z
# 40879           25  2018-06-13T04:00:05.000Z
# 40880           24  2018-06-13T16:00:03.000Z
#
# ...

# %%
US_YT["country"] = "USA"
US_YT.to_csv("USvideos.csv", index=False)

# %%
IN_YT["country"] = "India"
IN_YT.to_csv("INvideos.csv", index=False)

# %%
FR_YT["country"] = "France"
FR_YT.to_csv("FRvideos.csv", index=False)

# %%
DE_YT["country"] = "Germany"
DE_YT.to_csv("DEvideos.csv", index=False)

# %% [markdown]
# Third, merge 5 files together, to proceed with fuller analysis

# %%
import os
import glob
import pandas as pd

path = "c:/Users/User/Documents/GitHub/YouTube-Analysis"

all_files = glob.glob(os.path.join(path, "*.csv"))

combined_csv = pd.concat([pd.read_csv(f) for f in all_files ])

# %% [markdown]
# Lastly, you can see merged data frame here.

# %%
combined_csv.tail()
# Out:
#           video_id trending_date  \
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# 40944             AaronsAnimals           15  2018-05-18T13:00:04.000Z
# 40945                  zefrank1           22  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# ...

# %%
combined_csv.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
combined_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200746 entries, 0 to 40948
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   video_id                200746 non-null  object
#  1   trending_date           200746 non-null  object
#  2   title                   200746 non-null  object
#  3   channel_title           200746 non-null  object
#  4   category_id             200746 non-null  int64
#  5   publish_time            200746 non-null  object
#  6   tags                    200746 non-null  object
#  7   views                   200746 non-null  int64
#  8   likes                   200746 non-null  int64
#  9   dislikes                200746 non-null  int64
#  10  comment_count           200746 non-null  int64
#  11  thumbnail_link          200746 non-null  object
#  12  comments_disabled       200746 non-null  bool
#  13  ratings_disabled        200746 non-null  bool
# ...

# %% [markdown]
# As we can see there are 200746 entries in the dataset, however there are some null values in description column.

# %% [markdown]
# To do some data cleaning, and to get rid of those null values, we put an empty string in place of each null value in the description column

# %%
combined_csv["description"] = combined_csv["description"].fillna(value="")

# %%
combined_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200746 entries, 0 to 40948
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   video_id                200746 non-null  object
#  1   trending_date           200746 non-null  object
#  2   title                   200746 non-null  object
#  3   channel_title           200746 non-null  object
#  4   category_id             200746 non-null  int64
#  5   publish_time            200746 non-null  object
#  6   tags                    200746 non-null  object
#  7   views                   200746 non-null  int64
#  8   likes                   200746 non-null  int64
#  9   dislikes                200746 non-null  int64
#  10  comment_count           200746 non-null  int64
#  11  thumbnail_link          200746 non-null  object
#  12  comments_disabled       200746 non-null  bool
#  13  ratings_disabled        200746 non-null  bool
# ...

# %% [markdown]
# # 4.1 Statistical Info

# %%
combined_csv.describe()
# Out:
#          category_id         views         likes      dislikes  comment_count
# count  200746.000000  2.007460e+05  2.007460e+05  2.007460e+05   2.007460e+05
# mean       20.618448  1.120424e+06  3.622717e+04  1.925606e+03   4.186586e+03
# std         7.009922  4.196333e+06  1.417935e+05  1.908126e+04   2.301201e+04
# min         1.000000  2.230000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%        20.000000  6.945250e+04  9.980000e+02  6.200000e+01   1.380000e+02
# 50%        24.000000  2.581600e+05  5.008000e+03  2.480000e+02   6.310000e+02
# 75%        24.000000  8.121225e+05  2.171775e+04  8.950000e+02   2.353000e+03
# max        44.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %% [markdown]
# - mean views is 1,120,424
# - mean amount of likes is 36,327
# - mean amount of dislikes is 1,926
# - mean amount if comments is 4,187

# %%
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing some more packages for analysis

# %% [markdown]
# # 4.2 Ratio of trending videos by country

# %%
labels = combined_csv.groupby(['country']).count().index
sizes = combined_csv.groupby(['country']).count()['title']


fig, ax = plt.subplots(figsize=(8,8))
ax.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=False , startangle=90 )
ax.axis('equal') 
sizes
# Out:
# country
# Canada     40881
# France     40724
# Germany    40840
# India      37352
# USA        40949
# Name: title, dtype: int64

# %% [markdown]
# We see that 4 western countries have relatively same amount of trending videos - 40 000 (20% each), however India is a litte bit behind with around 35 000 videos (18.6%).

# %% [markdown]
# # 4.3 Analysis by Category

# %% [markdown]
# ## Which video category has the largest number of trending videos?

# %% [markdown]
# First, we will add a column that contains category names based on the values in category_id column. We will use a category JSON file provided.

# %%
import json

with open("US_category_id.json") as f:
    categories = json.load(f)["items"]
cat_dict = {}
for cat in categories:
    cat_dict[int(cat["id"])] = cat["snippet"]["title"]
combined_csv['category_name'] = combined_csv['category_id'].map(cat_dict)

# %%
combined_csv.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
cdf = combined_csv["category_name"].value_counts().to_frame().reset_index()
cdf.rename(columns={"index": "category_name", "category_name": "No_of_videos"}, inplace=True)
fig, ax = plt.subplots(figsize=(10,6))
_ = sns.barplot(x="category_name", y="No_of_videos", data=cdf)
_ = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
_ = ax.set(xlabel="Category", ylabel="No. of videos")
plt.title("Categories of trending videos by No. of videos")
# Out:
# Text(0.5, 1.0, 'Categories of trending videos by No. of videos')

# %% [markdown]
# We see that the Entertainment category contains the largest number of trending videos among other categories: around 65 000 videos, followed by People&Blogs category with around 20 000 videos, followed by Music category with around 20 000 videos, and so on.

# %% [markdown]
# ## Number of views by category in each country

# %%
cat_df_us = combined_csv[combined_csv['country']=='USA']['category_name'].value_counts().reset_index()
cat_df_ge = combined_csv[combined_csv['country']=='Germany']['category_name'].value_counts().reset_index()
plt.figure(figsize=(41, 10))

plt.subplot(1,3,1)
ax = sns.barplot(y=cat_df_us['index'],x=cat_df_us['category_name'], data=cat_df_us)
plt.xlabel("Number of Videos")
plt.ylabel("Categories")
plt.title("Categories of trend videos in USA")


plt.subplot(132)

ax = sns.barplot(y=cat_df_ge['index'],x=cat_df_ge['category_name'], data=cat_df_ge)
plt.xlabel("Number of Videos")
plt.ylabel("Categories")
plt.title("Categories of trend videos in Germany")



plt.show()

# %%
cat_df_in = combined_csv[combined_csv['country']=='India']['category_name'].value_counts().reset_index()
cat_df_fr = combined_csv[combined_csv['country']=='France']['category_name'].value_counts().reset_index()
cat_df_ca = combined_csv[combined_csv['country']=='Canada']['category_name'].value_counts().reset_index()

plt.figure(figsize=(41, 10))

plt.subplot(1,3,1)
ax = sns.barplot(y=cat_df_in['index'],x=cat_df_in['category_name'], data=cat_df_in)
plt.xlabel("Number of Videos")
plt.ylabel("Categories")
plt.title("Categories of trend videos in India")


plt.subplot(132)

ax = sns.barplot(y=cat_df_fr['index'],x=cat_df_fr['category_name'], data=cat_df_fr)
plt.xlabel("Number of Videos")
plt.ylabel("Categories")
plt.title("Categories of trend videos in France")



plt.show()

# %%
plt.figure(figsize=(20, 10))
ax = sns.barplot(y=cat_df_ca['index'],x=cat_df_ca['category_name'], data=cat_df_ca)
plt.xlabel("Number of Videos")
plt.ylabel("Categories")
plt.title("Categories of trend videos in Canada")
# Out:
# Text(0.5, 1.0, 'Categories of trend videos in Canada')

# %% [markdown]
# - In all countries most popular category is Entertainment.
# - Top-2 and top-3 in Canada is News&Politics and People&Blogs
# - Top-2 and top-3 in France is People&Blogs and Comedy
# - Top-2 and top-3 in India is News&Politics and Music
# - Top-2 and top-3 in USA is Music and How to&Style
# - Top-2 and top-3 in Germany is People&Blogs and News&Politics

# %% [markdown]
# # 4.4 How many comments, likes and dislikes videos have

# %%
plt.figure(figsize=(20, 10))


plt.subplot(2,2,1)
plt.hist(combined_csv[combined_csv["dislikes"] < 0.015e6]["dislikes"], bins=30)
plt.ylabel("No. videos", size=14)
plt.title("Dislikes", size=14)

plt.subplot(222)
plt.hist(combined_csv[combined_csv["comment_count"] < 0.01e6]["comment_count"], bins=30)
plt.ylabel("No. videos", size=14)
plt.title("Comments", size=14)
plt.show()

# %%
plt.figure(figsize=(20, 10))

plt.subplot(2,2,1)
plt.hist(combined_csv[combined_csv["views"] < 0.15e8]["views"], bins=30)
plt.ylabel("No. videos", size=14)
plt.title("Views", size=14)

plt.subplot(2,2,2)
plt.hist(combined_csv[combined_csv["likes"] < 0.5e6]["likes"], bins=30)
plt.ylabel("No. videos", size=14)
plt.title("Likes", size=14)
plt.show()

# %% [markdown]
# - majority of trending videos have less than 2 million views
# - majority of videos have less than 100000 likes and less than 2000 dislikes
# - majority of videos have less than 2000 comments

# %% [markdown]
# # 4.5 Likes/dislikes and views/comments ratio trending videos have by category

# %%
like_dislike_ratio = combined_csv.groupby('category_name')['likes'].agg('sum') / combined_csv.groupby('category_name')['dislikes'].agg('sum')
like_dislike_ratio = like_dislike_ratio.sort_values(ascending=False).reset_index()
like_dislike_ratio.columns = ['category_name','ratio']
plt.subplots(figsize=(10, 15))
sns.barplot(x="ratio", y="category_name", data=like_dislike_ratio,
            label="Likes/dislikes Ratio")

plt.title("Likes/dislikes ratio by category")
# Out:
# Text(0.5, 1.0, 'Likes/dislikes ratio by category')

# %%
views_comments_ratio = combined_csv.groupby('category_name')['views'].agg('sum') / combined_csv.groupby('category_name')['comment_count'].agg('sum')
views_comments_ratio = views_comments_ratio.sort_values(ascending=False).reset_index()
views_comments_ratio.columns = ['category_name','ratio']
plt.subplots(figsize=(10, 15))
sns.barplot(x="ratio", y="category_name", data=views_comments_ratio,
            label="Views/comments Ratio")

plt.title("Views/comments ratio by category")
# Out:
# Text(0.5, 1.0, 'Views/comments ratio by category')

# %% [markdown]
# - Pets & Animals videos have highest likes-dislikes ratio. Relatively most liked videos.
# - Nonprofit & Activism's videos have lowest likes-dislike ratio and views-comments ratio. People don't like these video and comment there a lot.
# - Movies is a category people rarely comment compatatively with views.

# %% [markdown]
# # 4.6 When was videos published?

# %%
import datetime

combined_csv['publish_month'] = combined_csv['publish_time']. apply(
    lambda x: datetime.datetime.strptime(x[:10], "%Y-%m-%d").date().strftime('%B'))

# %% [markdown]
# Using datetime library we are adding new column 'publish_month' into the dataset

# %%
combined_csv.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
mdf = combined_csv["publish_month"].value_counts().to_frame().reset_index()
mdf.rename(columns={"index": "publish_month", "publish_month": "No_of_videos"}, inplace=True)
fig, ax = plt.subplots(figsize=(10,6))
_ = sns.barplot(x="publish_month", y="No_of_videos", data=mdf)
_ = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
_ = ax.set(xlabel="Month", ylabel="No. of videos")

# %% [markdown]
# According to this barchart, most popular month for trending videos id May, December and March, least popular September, August and July

# %% [markdown]
# # 5. Conclusion

# %% [markdown]
# From the analysis that is provided above we can draw following conclusions.
#
# 1. Number of videos is evenly distribted between 5 countries, however, the least amount of trending views belongs to India.
# 2. According to analysis of categories, all 5 countries seems to view Entertainment videos the most. Other categories far behind it.
# 3. Majority of trending videos have less than 2 million views, less than 100000 likes and less than 2000 dislikes, less than 2000 comments, which is certainly not that huge.
# 4. According to likes/dislikes ratio people seem to enjoy Pets&Animals the most, which is understandable. However, we can see that people rather hate Activism category, probably because of antaginisation of politics in our society, which makes even more sence when we look into views/comments ratio - when pople hate something they can't keep it for themsrlves and comment a lot (relatively).
# 5. If you want to be on trend summer is a bad season for you
